# %% [markdown]
# # Overview of MATILDA.FT code
#
# This code is designed to perform coarse-grained, mesoscale simulations of polymeric and soft matter materials.
#
# #### Publications using this software:
#
# 1. {cite}`tilda`
#
# 2. {cite}`jedlinska2023effect`
#
# ```{bibliography} ./references.bib
# ```
